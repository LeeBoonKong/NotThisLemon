# %% [markdown]
# **One of the biggest hurdles of an auto dealership when it comes to purchasing a used car is the risk that the vehicle might have some serious problem that might prevent it from being sold to customers. Therefore it is of the utmost importance that the auto dealership would be able to figure this out before making the purchase which in turns allow them to provide a good inventory for their customer.**
#
# ** As a data scientist you have been hired to predict if the car auctioned is not worth buying (lemon). As this is a mock problem, you are allowed (for whatever reason) to only you use 2 types of Machine Learning algorithm which is XgBoost and implementation of Neural in Keras or Tensorflow. You need to show and explain the parameter tuning process for both.**
#
# **You can use either python script or Notebook but steps should be commented. Faster to run and easier code to read is a plus in the evaluation. **

# %% [markdown]
# **The data contains missing values, The dependent variable (Lemon) is binary (C2),
# There are 32 Independent variables (C3-C34)**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Training Data

# %%
Train = pd.read_csv('train.csv')
Train.head()
# Out:
#    RefId  Lemon? Date Purchased  Auction  Vehicle Year  Vehicle Age  \
# 0  26384       0      2/18/2009  MANHEIM          2002            7
# 1  20197       0      4/27/2010    OTHER          2005            5
# 2  46568       0       9/9/2009  MANHEIM          2004            5
# 3  36772       1      1/29/2010  MANHEIM          2004            6
# 4   1931       0     10/19/2009    ADESA          2006            3
#
#         Make                 Model Trim                SubModel      ...       \
# 0      DODGE   CARAVAN FWD V6 3.3L  Spo  MINIVAN 3.3L FFV SPORT      ...
# 1       FORD                 FOCUS  ZX5            4D SEDAN ZX5      ...
# 2  CHEVROLET    IMPALA 3.4L V6 SFI  Bas                4D SEDAN      ...
# 3     NISSAN   FRONTIER PICKUP 2WD   XE         EXT CAB 3.3L XE      ...
# 4      DODGE  CARAVAN GRAND FWD V6  SXT        MINIVAN 3.8L SXT      ...
#
#   MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  \
# ...

# %% [markdown]
# # Prediction Data

# %%
Predict = pd.read_csv('predictthis.csv')
Predict.head()
# Out:
#    RefId Date Purchased  Auction  Vehicle Year  Vehicle Age       Make  \
# 0  45941      4/21/2010  MANHEIM          2006            4    MERCURY
# 1  67400     11/10/2010    ADESA          2004            6  CHEVROLET
# 2  60537      2/27/2009    ADESA          2004            5  CHEVROLET
# 3  27262      8/26/2010    OTHER          2004            6       FORD
# 4   8027     11/20/2009  MANHEIM          2002            7    PONTIAC
#
#                   Model Trim             SubModel   Color      ...       \
# 0              MILAN V6  Bas             4D SEDAN  SILVER      ...
# 1             TAHOE 2WD   LS   4D SUV 5.3L FFV LS   GREEN      ...
# 2  SUBURBAN 1500 2WD 5.  150   4D UTILITY 5.3L LS   WHITE      ...
# 3                 FOCUS  ZTS         4D SEDAN ZTS    BLUE      ...
# 4               MONTANA  NaN  4D MINIVAN EXT 3.4L  MAROON      ...
#
#   MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice PRIMEUNIT  \
# ...

# %% [markdown]
# # Example answer format

# %%
Example = pd.read_csv('example.csv')
Example.head()
# Out:
#    Refid  Lemon?
# 0  73015       0
# 1  73016       0
# 2  73017       0
# 3  73018       0
# 4  73019       0
