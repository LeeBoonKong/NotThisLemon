# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    RefId  Lemon? Date Purchased  Auction  Vehicle Year  Vehicle Age  \
# 0  26384       0      2/18/2009  MANHEIM          2002            7
# 1  20197       0      4/27/2010    OTHER          2005            5
# 2  46568       0       9/9/2009  MANHEIM          2004            5
# 3  36772       1      1/29/2010  MANHEIM          2004            6
# 4   1931       0     10/19/2009    ADESA          2006            3
#
#         Make                 Model Trim                SubModel      ...       \
# 0      DODGE   CARAVAN FWD V6 3.3L  Spo  MINIVAN 3.3L FFV SPORT      ...
# 1       FORD                 FOCUS  ZX5            4D SEDAN ZX5      ...
# 2  CHEVROLET    IMPALA 3.4L V6 SFI  Bas                4D SEDAN      ...
# 3     NISSAN   FRONTIER PICKUP 2WD   XE         EXT CAB 3.3L XE      ...
# 4      DODGE  CARAVAN GRAND FWD V6  SXT        MINIVAN 3.8L SXT      ...
#
#   MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43789 entries, 0 to 43788
# Data columns (total 34 columns):
# RefId                                43789 non-null int64
# Lemon?                               43789 non-null int64
# Date Purchased                       43789 non-null object
# Auction                              43789 non-null object
# Vehicle Year                         43789 non-null int64
# Vehicle Age                          43789 non-null int64
# Make                                 43789 non-null object
# Model                                43789 non-null object
# Trim                                 42393 non-null object
# SubModel                             43784 non-null object
# Color                                43784 non-null object
# Transmission                         43783 non-null object
# WheelTypeID                          41907 non-null float64
# WheelType                            41904 non-null object
# ...

# %%
#prediction is the result that needs to be predicted
#predictor is all the factor to do predictions
prediction = ['Lemon?']
predictor = list(df.drop(prediction, axis=1))
predictor
# Out:
# ['RefId',
#  'Date Purchased',
#  'Auction',
#  'Vehicle Year',
#  'Vehicle Age',
#  'Make',
#  'Model',
#  'Trim',
#  'SubModel',
#  'Color',
#  'Transmission',
#  'WheelTypeID',
#  'WheelType',
#  'VehOdo',
#  'Nationality',
#  'Size',
#  'TopThreeAmericanName',
#  'MMRAcquisitionAuctionAveragePrice',
#  'MMRAcquisitionAuctionCleanPrice',
#  'MMRAcquisitionRetailAveragePrice',
#  'MMRAcquisitonRetailCleanPrice',
#  'MMRCurrentAuctionAveragePrice',
#  'MMRCurrentAuctionCleanPrice',
#  'MMRCurrentRetailAveragePrice',
#  'MMRCurrentRetailCleanPrice',
#  'PRIMEUNIT',
#  'AUCGUART',
#  'BYRNO',
#  'VNZIP1',
#  'VNST',
#  'VehBCost',
#  'IsOnlineSale',
#  'WarrantyCost']

# %% [markdown]
# # Categorical datas
#
# ## 1. Auction
# ## 2. Make
# ## 3. Trim
# ## 4. Color
# ## 5. Transmission
# ## 6. WheelTypeID = WheelType
# ####      drop WheelTypeID
# ## 7. Nationality
# ## 8. Size
# ## 9. TopThreeAmericanName
# ## 10. PRIMEUNIT
# ####       Yes/No >> Change yes to 1, No to -1, missing values to 0
# ## 11. AUCGUART
# ####      Green/Red, Green 1, Red -1, missng values 0
# ## 12. VNST

# %%
#Steps
#Drop Unuseful columns
#Columns to drop: WheelTypeID, RefID
#Fill in missing values
#One Hot Encode values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-79372e2f446b> in <module>()
#       5 #One Hot Encode values
#       6
# ----> 7 sns.heatmap(df)
#
# ~/anaconda3_501/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/anaconda3_501/lib/python3.6/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...
